# %%
#Here Import libarary
import play_scraper
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#using play_scraper libaray so I can extract data about apps with keyword 'wellbeing'
dataset = play_scraper.search('wellbeing',page=2,detailed = True)

# %%
#I create empty dataframe with columns of the data I want to concerate at 
mydataframe = pd.DataFrame(columns=['title','icon','category','score','reviews','description','editors_choice','free','updated','installs','content_rating'])

# %%
list1 = ['title','icon','category','score','reviews','description','editors_choice','free','updated','installs','content_rating']

# %%
#Create a loop to go through the list of data which have dictionary values 
for i in range(len(dataset)):
    data1= { k: dataset[i][k]  for k in list1 }
    mydataframe = mydataframe.append(data1,ignore_index=True)
    print (mydataframe.head())
# Out:
#                title                                               icon  \
# 0  Digital Wellbeing  https://lh3.googleusercontent.com/d74zkuWfVBFW...
#
#   category score reviews                                        description  \
# 0  [TOOLS]   4.2   95714  See a complete picture of your digital habits ...
#
#   editors_choice  free            updated installs content_rating
# 0          False  True  February 24, 2020       1+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
#
#                                                 icon           category score  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...            [TOOLS]   4.2
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...  [PERSONALIZATION]   3.9
#
#   reviews                                        description editors_choice  \
# 0   95714  See a complete picture of your digital habits ...          False
# 1    5480  ActionDash takes the Digital Wellbeing app as ...          False
#
#    free            updated  installs content_rating
# 0  True  February 24, 2020        1+     [Everyone]
# 1  True    January 3, 2020  500,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# ...
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating
# 0          False  True  February 24, 2020        1+     [Everyone]
# 1          False  True    January 3, 2020  500,000+     [Everyone]
# 2          False  True      April 6, 2020    5,000+     [Everyone]
# 3          False  True     March 18, 2020  100,000+     [Everyone]
# 4          False  True     March 24, 2020   10,000+     [Everyone]

# %%
mydataframe['rank'] = mydataframe.index+1

# %%
mydataframe['keyword']='wellbeing'

# %%
mydataframe.head()
# Out:
#                                                title  \
# 0                                  Digital Wellbeing
# 1  ActionDash: Digital Wellbeing & Screen Time he...
# 2                                 Navigate Wellbeing
# 3          Digitox : Digital Wellbeing - Screen Time
# 4                      Whil: wellbeing & mindfulness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1  https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2  https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4  https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2   95714  See a complete picture of your digital habits ...
# 1   3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2   3.9      60  The Navigate Wellbeing App is a convenient and...
# 3   4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4   4.7     389  Whil’s award-winning digital wellbeing and min...
#
#   editors_choice  free            updated  installs content_rating  rank  \
# 0          False  True  February 24, 2020        1+     [Everyone]     1
# 1          False  True    January 3, 2020  500,000+     [Everyone]     2
# 2          False  True      April 6, 2020    5,000+     [Everyone]     3
# 3          False  True     March 18, 2020  100,000+     [Everyone]     4
# 4          False  True     March 24, 2020   10,000+     [Everyone]     5
#
#      keyword
# 0  wellbeing
# 1  wellbeing
# 2  wellbeing
# 3  wellbeing
# 4  wellbeing

# %%
df = play_scraper.search('wellness',page=2,detailed = True)

# %%
mydataframe1 = pd.DataFrame(columns=['title','icon','category','score','reviews','description','editors_choice','free','updated','installs','content_rating'])

# %%
for i in range(len(df)):
    data2= { k: df[i][k]  for k in list1 }
    mydataframe1 = mydataframe1.append(data2,ignore_index=True)
    print (mydataframe1.head())
# Out:
#                  title                                               icon  \
# 0  The Wellness Corner  https://lh3.googleusercontent.com/0YvYxhBCuCYs...
#
#                category score reviews  \
# 0  [HEALTH_AND_FITNESS]   4.2     341
#
#                                          description editors_choice  free  \
# 0  If you are seeking a one-stop destination for ...          False  True
#
#           updated installs content_rating
# 0  March 20, 2020  10,000+     [Everyone]
#                  title                                               icon  \
# 0  The Wellness Corner  https://lh3.googleusercontent.com/0YvYxhBCuCYs...
# 1           mywellness  https://lh3.googleusercontent.com/vF7N7EqDcwZp...
#
#                category score reviews  \
# 0  [HEALTH_AND_FITNESS]   4.2     341
# 1  [HEALTH_AND_FITNESS]   3.4    6158
#
#                                          description editors_choice  free  \
# 0  If you are seeking a one-stop destination for ...          False  True
# 1  Mywellness app by Technogym helps you to get t...          False  True
#
#           updated    installs content_rating
# 0  March 20, 2020     10,000+     [Everyone]
# 1   March 3, 2020  1,000,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# ...
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]
#                                                title  \
# 0                                The Wellness Corner
# 1                                         mywellness
# 2  Daily Burst | Simple Wellness, Advice, Inspira...
# 3                              Wellness At Your Side
# 4                                 AlwaysOn® Wellness
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/0YvYxhBCuCYs...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/vF7N7EqDcwZp...  [HEALTH_AND_FITNESS]
# 2  https://lh3.googleusercontent.com/lwEboB7bOzz5...  [HEALTH_AND_FITNESS]
# 3  https://lh3.googleusercontent.com/LP9C9tFQQfOz...  [HEALTH_AND_FITNESS]
# 4  https://lh3.googleusercontent.com/IIqXpZ-D-Ssr...  [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   4.2     341  If you are seeking a one-stop destination for ...
# 1   3.4    6158  Mywellness app by Technogym helps you to get t...
# 2   4.7     233  DailyBurst is a once daily personal developmen...
# 3   2.6      68  Do you have an account with WebMD Health Servi...
# 4   2.6     507  AlwaysOn® Wellness connects you with your orga...
#
#   editors_choice  free            updated    installs content_rating
# 0          False  True     March 20, 2020     10,000+     [Everyone]
# 1          False  True      March 3, 2020  1,000,000+     [Everyone]
# 2          False  True  December 14, 2018     10,000+     [Everyone]
# 3          False  True  February 14, 2020     10,000+     [Everyone]
# 4          False  True      March 3, 2020     10,000+     [Everyone]

# %%
mydataframe1['rank'] = mydataframe1.index+1

# %%
mydataframe1['keyword'] = 'wellness'

# %%
df1 = play_scraper.search('wholeness',page=2,detailed=True)
mydataframe2 = pd.DataFrame(columns=['title','icon','category','score','reviews','description','editors_choice','free','updated','installs','content_rating'])
for i in range(len(df1)):
    data3= { k: df1[i][k]  for k in list1 }
    mydataframe2 = mydataframe2.append(data3,ignore_index=True)
    print (mydataframe2.head())
# Out:
#         title                                               icon  \
# 0  HealthyNow  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
#
#                category score reviews  \
# 0  [HEALTH_AND_FITNESS]   1.3     511
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
#
#           updated  installs content_rating
# 0  March 30, 2017  100,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
#
#                                                 icon              category  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...  [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...           [LIFESTYLE]
#
#   score reviews                                        description  \
# 0   1.3     511  HealthyNow is the mobile complement to the ind...
# 1   4.7     746  How many negative thoughts have been endlessly...
#
#   editors_choice  free         updated  installs content_rating
# 0          False  True  March 30, 2017  100,000+     [Everyone]
# 1          False  True   March 6, 2020   50,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
#
#                                                 icon               category  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...   [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...            [LIFESTYLE]
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...  [BOOKS_AND_REFERENCE]
#
#   score reviews                                        description  \
# 0   1.3     511  HealthyNow is the mobile complement to the ind...
# 1   4.7     746  How many negative thoughts have been endlessly...
# 2   4.6     148  Your life is a result of creation of your mind...
#
#   editors_choice  free         updated  installs content_rating
# 0          False  True  March 30, 2017  100,000+     [Everyone]
# 1          False  True   March 6, 2020   50,000+     [Everyone]
# 2          False  True   April 4, 2020   50,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
#
#                                                 icon               category  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...   [HEALTH_AND_FITNESS]
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...            [LIFESTYLE]
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...  [BOOKS_AND_REFERENCE]
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...   [HEALTH_AND_FITNESS]
#
#   score reviews                                        description  \
# 0   1.3     511  HealthyNow is the mobile complement to the ind...
# 1   4.7     746  How many negative thoughts have been endlessly...
# 2   4.6     148  Your life is a result of creation of your mind...
# 3   4.6    6244  Download the Synctuition app for free to exper...
#
#   editors_choice  free         updated  installs content_rating
# 0          False  True  March 30, 2017  100,000+     [Everyone]
# 1          False  True   March 6, 2020   50,000+     [Everyone]
# 2          False  True   April 4, 2020   50,000+     [Everyone]
# 3          False  True   April 5, 2020  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
# ...
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]
#                                                title  \
# 0                                         HealthyNow
# 1  I am - Daily affirmations reminders for self care
# 2             The Secret of Everything: Spirituality
# 3                     Synctuition Meditation Program
# 4                     ST (JiJi) Math: School Version
#
#                                                 icon  \
# 0  https://lh3.googleusercontent.com/GSaRu_qQfOx5...
# 1  https://lh3.googleusercontent.com/3a-ZFQ5boxg5...
# 2  https://lh3.googleusercontent.com/gYAUEUfaPGBf...
# 3  https://lh3.googleusercontent.com/KpDIdDVhmoqB...
# 4  https://lh3.googleusercontent.com/xqlQXGObJeVT...
#
#                         category score reviews  \
# 0           [HEALTH_AND_FITNESS]   1.3     511
# 1                    [LIFESTYLE]   4.7     746
# 2          [BOOKS_AND_REFERENCE]   4.6     148
# 3           [HEALTH_AND_FITNESS]   4.6    6244
# 4  [EDUCATION, FAMILY_EDUCATION]   3.9    7871
#
#                                          description editors_choice  free  \
# 0  HealthyNow is the mobile complement to the ind...          False  True
# 1  How many negative thoughts have been endlessly...          False  True
# 2  Your life is a result of creation of your mind...          False  True
# 3  Download the Synctuition app for free to exper...          False  True
# 4  This app allows schools to access their ST Mat...          False  True
#
#               updated  installs content_rating
# 0      March 30, 2017  100,000+     [Everyone]
# 1       March 6, 2020   50,000+     [Everyone]
# 2       April 4, 2020   50,000+     [Everyone]
# 3       April 5, 2020  500,000+     [Everyone]
# 4  September 25, 2019  500,000+     [Everyone]

# %%
mydataframe2['rank']=mydataframe2.index+1
mydataframe2['keyword'] = 'wholeness'

# %%
df2 = play_scraper.search('mental health',page=2,detailed=True)
mydataframe3 = pd.DataFrame(columns=['title','icon','category','score','reviews','description','editors_choice','free','updated','installs','content_rating'])
for i in range(len(df2)):
    data4= { k: df2[i][k]  for k in list1 }
    mydataframe3 = mydataframe3.append(data3,ignore_index=True)
    print (mydataframe3.head())
# Out:
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
# ...
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]

# %%
mydataframe3['rank']=mydataframe3.index+1
mydataframe3['keyword'] = 'mental health'

# %%
df3 = play_scraper.search('mindfulness',page=2,detailed=True)
mydataframe4 = pd.DataFrame(columns=['title','icon','category','score','reviews','description','editors_choice','free','updated','installs','content_rating'])
for i in range(len(df3)):
    data4= { k: df3[i][k]  for k in list1 }
    mydataframe4 = mydataframe4.append(data3,ignore_index=True)
    print (mydataframe4.head())
# Out:
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
# ...
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]
#                                                title  \
# 0  Habits - Law of Success, Prosperity, and Happi...
# 1  Habits - Law of Success, Prosperity, and Happi...
# 2  Habits - Law of Success, Prosperity, and Happi...
# 3  Habits - Law of Success, Prosperity, and Happi...
# 4  Habits - Law of Success, Prosperity, and Happi...
#
#                                                 icon     category score  \
# 0  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 1  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 2  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 3  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
# 4  https://lh3.googleusercontent.com/tCBPg34duBGS...  [LIFESTYLE]   4.6
#
#   reviews                                        description editors_choice  \
# 0    2512  Habits\napp is an educational, learning, and r...          False
# 1    2512  Habits\napp is an educational, learning, and r...          False
# 2    2512  Habits\napp is an educational, learning, and r...          False
# 3    2512  Habits\napp is an educational, learning, and r...          False
# 4    2512  Habits\napp is an educational, learning, and r...          False
#
#    free        updated  installs  content_rating
# 0  True  April 3, 2019  500,000+  [Everyone 10+]
# 1  True  April 3, 2019  500,000+  [Everyone 10+]
# 2  True  April 3, 2019  500,000+  [Everyone 10+]
# 3  True  April 3, 2019  500,000+  [Everyone 10+]
# 4  True  April 3, 2019  500,000+  [Everyone 10+]

# %%
mydataframe4['rank']=mydataframe4.index+1
mydataframe4['keyword'] = 'mindfulness'

# %%
frames = [mydataframe, mydataframe1, mydataframe2,mydataframe3,mydataframe4]

Data = pd.concat(frames)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 49
# Data columns (total 13 columns):
# title             250 non-null object
# icon              250 non-null object
# category          250 non-null object
# score             232 non-null object
# reviews           250 non-null object
# description       250 non-null object
# editors_choice    250 non-null object
# free              250 non-null object
# updated           250 non-null object
# installs          250 non-null object
# content_rating    250 non-null object
# rank              250 non-null int64
# keyword           250 non-null object
# dtypes: int64(1), object(12)
# memory usage: 27.3+ KB

# %%
Data['updated'] = pd.to_datetime(Data['updated'])
Data['keyword'] = Data.keyword.astype('str') 
Data['editors_choice'] = Data.editors_choice.astype('category')
Data['free'] = Data.free.astype('category')

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 49
# Data columns (total 13 columns):
# title             250 non-null object
# icon              250 non-null object
# category          250 non-null object
# score             232 non-null object
# reviews           250 non-null object
# description       250 non-null object
# editors_choice    250 non-null category
# free              250 non-null category
# updated           250 non-null datetime64[ns]
# installs          250 non-null object
# content_rating    250 non-null object
# rank              250 non-null int64
# keyword           250 non-null object
# dtypes: category(2), datetime64[ns](1), int64(1), object(9)
# memory usage: 24.1+ KB

# %%
Data
# Out:
#                                                 title  \
# 0                                   Digital Wellbeing
# 1   ActionDash: Digital Wellbeing & Screen Time he...
# 2                                  Navigate Wellbeing
# 3           Digitox : Digital Wellbeing - Screen Time
# 4                       Whil: wellbeing & mindfulness
# ..                                                ...
# 45  Habits - Law of Success, Prosperity, and Happi...
# 46  Habits - Law of Success, Prosperity, and Happi...
# 47  Habits - Law of Success, Prosperity, and Happi...
# 48  Habits - Law of Success, Prosperity, and Happi...
# 49  Habits - Law of Success, Prosperity, and Happi...
#
#                                                  icon              category  \
# 0   https://lh3.googleusercontent.com/d74zkuWfVBFW...               [TOOLS]
# 1   https://lh3.googleusercontent.com/6p1VWcUoaVFs...     [PERSONALIZATION]
# 2   https://lh3.googleusercontent.com/-5ShSroNdfbE...  [HEALTH_AND_FITNESS]
# 3   https://lh3.googleusercontent.com/Wg7CdCIsLqh_...     [PERSONALIZATION]
# 4   https://lh3.googleusercontent.com/NI2MxPeR0BmD...  [HEALTH_AND_FITNESS]
# ..                                                ...                   ...
# 45  https://lh3.googleusercontent.com/tCBPg34duBGS...           [LIFESTYLE]
# 46  https://lh3.googleusercontent.com/tCBPg34duBGS...           [LIFESTYLE]
# 47  https://lh3.googleusercontent.com/tCBPg34duBGS...           [LIFESTYLE]
# 48  https://lh3.googleusercontent.com/tCBPg34duBGS...           [LIFESTYLE]
# 49  https://lh3.googleusercontent.com/tCBPg34duBGS...           [LIFESTYLE]
#
#    score reviews                                        description  \
# 0    4.2   95714  See a complete picture of your digital habits ...
# 1    3.9    5480  ActionDash takes the Digital Wellbeing app as ...
# 2    3.9      60  The Navigate Wellbeing App is a convenient and...
# 3    4.1    1214  Why\nDigital Wellbeing\n?\nDo you feel that yo...
# 4    4.7     389  Whil’s award-winning digital wellbeing and min...
# ..   ...     ...                                                ...
# 45   4.6    2512  Habits\napp is an educational, learning, and r...
# 46   4.6    2512  Habits\napp is an educational, learning, and r...
# 47   4.6    2512  Habits\napp is an educational, learning, and r...
# 48   4.6    2512  Habits\napp is an educational, learning, and r...
# 49   4.6    2512  Habits\napp is an educational, learning, and r...
#
#    editors_choice  free    updated  installs  content_rating  rank  \
# 0           False  True 2020-02-24        1+      [Everyone]     1
# 1           False  True 2020-01-03  500,000+      [Everyone]     2
# 2           False  True 2020-04-06    5,000+      [Everyone]     3
# 3           False  True 2020-03-18  100,000+      [Everyone]     4
# 4           False  True 2020-03-24   10,000+      [Everyone]     5
# ..            ...   ...        ...       ...             ...   ...
# 45          False  True 2019-04-03  500,000+  [Everyone 10+]    46
# 46          False  True 2019-04-03  500,000+  [Everyone 10+]    47
# 47          False  True 2019-04-03  500,000+  [Everyone 10+]    48
# 48          False  True 2019-04-03  500,000+  [Everyone 10+]    49
# 49          False  True 2019-04-03  500,000+  [Everyone 10+]    50
#
#         keyword
# 0     wellbeing
# 1     wellbeing
# 2     wellbeing
# 3     wellbeing
# 4     wellbeing
# ..          ...
# 45  mindfulness
# 46  mindfulness
# 47  mindfulness
# 48  mindfulness
# 49  mindfulness
#
# [250 rows x 13 columns]

# %%
Data['title'].nunique()
# Out:
# 148
