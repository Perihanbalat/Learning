# %% [markdown]
# ## The main objective of this notebook is to explore the public income statement files

# %%
import pandas as pd
import zipfile
import os

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
import re
def getIndicatorsValues(df,row_index):
    row = (df.iloc[row_index]).iloc[2:]
    list_values = [str(row.iloc[i]) for i in range(len(row)) if i%2==1]
    for i in range(len(list_values)):
        if re.findall("[a-zA-Z]",list_values[i]):
            list_values[i] = np.NaN
        else:
            list_values[i] = float(list_values[i])
    return pd.Series(list_values)

def getListOfDates(df, row_index):
    '''
    Get all the dates in a file in Date format
    inputs: A datframe containing the data of a file and a index of a row 
    output: The list of all the dates in the file
    Exception: The row index doesn"t exist or the dataframe doesn't exist
    '''
    row = (df.iloc[row_index]).iloc[2:]
    return pd.Series([row.iloc[i] for i in range(len(row)) if i%2 == 0 and i!=0])

def get_file_identifier(df):
    '''
    return the identifier of a file
    input: dataframe
    output:String representing the identifier of a file
    '''
    try:
        return df.iloc[0,0]
    except Exception as ex:
        print(ex)

# %%
#Create a dictionnary with Date and Indicators values
def getDataDict(df):
    datadict = {}
    datadict["CompanyId"] = get_file_identifier(df)
    #A problem to solve: get the right cells for date
    datadict["Dates"]= getListOfDates(df,1)
    for i in range(df.shape[0]):
        datadict[getIndicatorName(df,i)]= getIndicatorsValues(df,i)
        
    return datadict

# %%
#NotebookApp.iopub_data_rate_limit=10000000.0 (bytes/sec)
#NotebookApp.rate_limit_window=3.0 (secs)

# Take a  file, get a new dataframe with indicators in columns and dates as index
def dfToDf(df):
    
    df_dict = getDataDict(df)
    return pd.DataFrame(df_dict)

# %%
#A function take a  zip of csv files and transform it to a Dataframe with all csv files data
def transform(zipFile, delimiter):
    """
    input: the zip file and a  delimiter for the csv files
    
    output: A dataframe containing all the data for the zip file
    
    """
    zf = zipfile.ZipFile(zipFile)
    
    textfiles = zf.infolist()
    
    list_ = []
    
    for textfile in textfiles:
        csv_file = zf.open(textfile.filename)
        
        first_line =  str(csv_file.readline())
        
        num_cols = first_line.count(delimiter)
        
        df = pd.read_csv(csv_file, header = None, parse_dates = [i for i in range(num_cols) if  i%2 == 0 and i!=0])
        
        dfnew  = dfToDf(df)
        
        list_.append(dfnew)
    
    frame = pd.concat(list_, axis = 0)
    
   
    
    return frame

# %%
dfs_software_public_income = transform('software_public_quarterly_income_statements_1.zip', ',')

# %%
dfs_software_public_income.set_index("Dates",inplace=True)

# %%
dfs_software_public_income.head(8)
# Out:
#         CompanyId  IQ_OTHER_UNUSUAL_SUPPL  IQ_NI_COMPANY  IQ_RESTRUCTURE  \
# Dates
# NaT    IQ34280323                     NaN      -2.979612             NaN
# NaT    IQ34280323                     NaN      -1.260563             NaN
# NaT    IQ34280323                     NaN       0.974995             NaN
# NaT    IQ34280323                     NaN      -0.088424             NaN
# NaT    IQ34280323                     NaN      -1.465225             NaN
# NaT    IQ34280323                     NaN      -0.520270             NaN
# NaT    IQ34280323                     NaN       3.738703             NaN
# NaT    IQ34280323                     NaN       0.494014             NaN
#
#        IQ_COST_REV  IQ_OTHER_OPER  IQ_RD_EXP_FN  IQ_DILUT_EPS_EXCL  \
# Dates
# NaT      -1.686575            NaN           NaN          -0.062125
# NaT       5.813539            NaN           NaN          -0.023960
# NaT       5.397071            NaN           NaN           0.015496
# NaT       5.001677            NaN           NaN          -0.003307
# NaT      -0.345158            NaN           NaN          -0.029490
# NaT       4.892946            NaN           NaN          -0.010000
# NaT       4.671531            NaN           NaN           0.070000
# NaT       4.161289            NaN           NaN           0.007984
#
#        IQ_EBITDA_EXCL_SBC  IQ_NI_NORM  ...  IQ_TOTAL_UNUSUAL_SUPPLE  \
# Dates                                  ...
# NaT             -2.448205   -1.680971  ...                      NaN
# NaT             -1.494750   -1.104248  ...                      NaN
# NaT              1.413825    0.734434  ...                      NaN
# NaT              0.006088   -0.134695  ...                      NaN
# NaT             -1.946971   -1.358212  ...                      NaN
# NaT             -0.360704   -0.440245  ...                      NaN
# NaT              3.001414    2.780149  ...                      NaN
# NaT              0.984304    0.418940  ...                      NaN
#
#        IQ_PERIODLENGTH_IS    IQ_EBT  IQ_EBITA  IQ_OTHER_NON_OPER_EXP_SUPPL  \
# Dates
# NaT                   3.0 -2.974936 -2.486833                          NaN
# NaT                   3.0 -1.686896 -1.533378                          NaN
# NaT                   3.0  1.378918  1.375197                          NaN
# NaT                   3.0 -0.067568 -0.032540                          NaN
# NaT                   3.0 -1.936756 -1.978318                    -0.000634
# NaT                   3.0 -0.704392 -0.621659                          NaN
# NaT                   3.0  4.448238  2.726325                          NaN
# NaT                   3.0  0.670304  0.693764                          NaN
#
#        IQ_EBITA_EXCL_SBC  IQ_DILUT_EPS_NORM  IQ_RESTATEMENT_IS  \
# Dates
# NaT            -2.486833          -0.033572                NaN
# NaT            -1.533378          -0.020189                NaN
# NaT             1.375197           0.013427                NaN
# NaT            -0.032540          -0.002462                NaN
# NaT            -1.978318          -0.024832                NaN
# NaT            -0.621659          -0.008461                NaN
# NaT             2.726325           0.052052                NaN
# NaT             0.693764           0.006770                NaN
#
#        IQ_TOTAL_REV_SHARE  IQ_EBITA_EQ_INC_EXCL_SBC
# Dates
# NaT              0.076811                 -2.486833
# NaT              0.078255                 -1.533378
# NaT              0.123819                  1.375197
# NaT              0.090852                 -0.032540
# NaT              0.106449                 -1.978318
# NaT              0.125782                 -0.621659
# NaT              0.180506                  4.471451
# NaT              0.115617                  0.693764
#
# [8 rows x 77 columns]

# %%
#Get the number of duplicate dates 
duplic = dfs_software_public_income.index.get_duplicates()
print(duplic)
# Out:
# DatetimeIndex([       'NaT', '2010-12-20', '2017-05-03', '2017-12-02',
#                '2018-05-02', '2018-12-03', '2013-07-25', '2014-03-03',
#                '2019-09-23', '2012-11-26',
#                ...
#                '2019-09-26', '2017-02-23', '2019-02-28', '2016-03-03',
#                '2019-04-26', '2008-05-30', '2015-03-31', '2017-07-25',
#                '2018-03-13', '2012-06-06'],
#               dtype='datetime64[ns]', name='Dates', length=260, freq=None)
# /home/mbousso/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: 'get_duplicates' is deprecated and will be removed in a future release. You can use idx[idx.duplicated()].unique() instead

# %%
dfs_health_public_income = transform('health_public_quarterly_income_statements_1.zip', ',')

# %%
dfs_health_public_income.set_index("Dates",inplace=True)

# %%
dfs_health_public_income.head(8)
# Out:
#              CompanyId  IQ_OTHER_UNUSUAL_SUPPL  IQ_NI_COMPANY  IQ_RESTRUCTURE  \
# Dates
# 2010-05-18  IQ24657663                     NaN     -17.015579             NaN
# 2010-08-20  IQ24657663                     NaN      -3.466000             NaN
# 2010-11-05  IQ24657663                     NaN      -2.874000             NaN
# 2011-04-01  IQ24657663                     NaN      -3.050000             NaN
# 2011-04-18  IQ24657663                     NaN      -8.168226             NaN
# 2011-08-26  IQ24657663                     NaN      -2.372000             NaN
# 2011-11-10  IQ24657663                     NaN      -2.755000             NaN
# 2012-03-01  IQ24657663                     NaN      -2.863000             NaN
#
#             IQ_COST_REV  IQ_OTHER_OPER  IQ_RD_EXP_FN  IQ_DILUT_EPS_EXCL  \
# Dates
# 2010-05-18     0.672007       0.038442           NaN         -15.630368
# 2010-08-20     1.923000       0.007000           NaN          -2.864678
# 2010-11-05     1.242000       0.005000           NaN          -2.043156
# 2011-04-01     1.473000       0.010000           NaN          -2.199999
# 2011-04-18     0.225269      -0.022000           NaN          -4.048724
# 2011-08-26     1.197000       0.003000           NaN          -1.000000
# 2011-11-10     1.611000       0.042000           NaN          -1.500000
# 2012-03-01     2.115000       0.007000           NaN          -0.700000
#
#             IQ_EBITDA_EXCL_SBC  IQ_NI_NORM  ...  IQ_TOTAL_UNUSUAL_SUPPLE  \
# Dates                                       ...
# 2010-05-18           -5.222399   -3.468969  ...                      NaN
# 2010-08-20           -3.120000   -2.166250  ...                      NaN
# 2010-11-05           -2.579000   -1.796250  ...                      NaN
# 2011-04-01           -2.750000   -1.906250  ...                      NaN
# 2011-04-18           -2.896727   -2.018413  ...                      NaN
# 2011-08-26           -2.009000   -1.488750  ...                      NaN
# 2011-11-10           -2.427000   -1.728125  ...                      NaN
# 2012-03-01           -2.577000   -1.796250  ...                      NaN
#
#             IQ_PERIODLENGTH_IS     IQ_EBT  IQ_EBITA  \
# Dates
# 2010-05-18                 3.0 -11.492489 -5.358695
# 2010-08-20                 3.0  -3.466000 -3.373000
# 2010-11-05                 3.0  -2.874000 -2.599000
# 2011-04-01                 3.0  -3.050000 -3.010000
# 2011-04-18                 3.0  -3.378746 -3.223270
# 2011-08-26                 3.0  -2.382000 -2.336000
# 2011-11-10                 3.0  -2.765000 -2.739000
# 2012-03-01                 3.0  -2.874000 -2.860000
#
#             IQ_OTHER_NON_OPER_EXP_SUPPL  IQ_EBITA_EXCL_SBC  IQ_DILUT_EPS_NORM  \
# Dates
# 2010-05-18                          NaN          -5.358695          -3.186565
# 2010-08-20                          NaN          -3.373000          -1.790423
# 2010-11-05                          NaN          -2.599000          -1.276972
# 2011-04-01                          NaN          -3.010000          -1.355172
# 2011-04-18                          NaN          -3.223270          -1.000103
# 2011-08-26                          NaN          -2.336000          -0.605432
# 2011-11-10                          NaN          -2.739000          -0.702780
# 2012-03-01                          NaN          -2.860000          -0.436811
#
#             IQ_RESTATEMENT_IS  IQ_TOTAL_REV_SHARE  IQ_EBITA_EQ_INC_EXCL_SBC
# Dates
# 2010-05-18                NaN            0.096133                 -5.358695
# 2010-08-20                NaN            0.100007                 -3.373000
# 2010-11-05                NaN            0.106636                 -2.599000
# 2011-04-01                NaN            0.194078                 -3.010000
# 2011-04-18                NaN            0.289518                 -3.223270
# 2011-08-26                NaN            0.285483                 -2.336000
# 2011-11-10                NaN            0.381865                 -2.739000
# 2012-03-01                NaN            0.273333                 -2.860000
#
# [8 rows x 77 columns]

# %%
dfs_health_public_income.index[dfs_health_public_income.index.duplicated()].unique()
# Out:
# DatetimeIndex(['2018-05-15', '2019-08-28', '2019-04-17', '2015-06-08',
#                '2015-09-30', '2016-06-23', '2016-09-30', '2017-08-31',
#                '2018-05-10', '2018-08-10',
#                ...
#                '2015-03-04', '2016-03-03', '2017-04-30', '2017-11-24',
#                '2010-08-17', '2011-03-02', '2019-02-21', '2015-02-16',
#                '2015-05-30', '2016-10-19'],
#               dtype='datetime64[ns]', name='Dates', length=1610, freq=None)

# %%
dfs_software_private_income = transform('software_private_annual_income_statements.zip', ',')

# %%
dfs_software_private_income.set_index("Dates",inplace=True)

# %%
dfs_software_private_income.head(4)
# Out:
#          CompanyId  IQ_OTHER_UNUSUAL_SUPPL  IQ_NI_COMPANY  IQ_RESTRUCTURE  \
# Dates
# NaT    IQ145536370                     NaN            NaN             NaN
# NaT    IQ145536370                     NaN            NaN             NaN
# NaT    IQ145536370                     NaN            NaN             NaN
# NaT    IQ145536370                     NaN            NaN             NaN
#
#        IQ_COST_REV  IQ_OTHER_OPER  IQ_RD_EXP_FN  IQ_DILUT_EPS_EXCL  \
# Dates
# NaT            NaN          2.253           NaN                NaN
# NaT            NaN          2.126           NaN                NaN
# NaT            NaN          4.054           NaN                NaN
# NaT            NaN          5.630           NaN                NaN
#
#        IQ_EBITDA_EXCL_SBC  IQ_NI_NORM  ...  IQ_TOTAL_UNUSUAL_SUPPLE  \
# Dates                                  ...
# NaT                   NaN         NaN  ...                      NaN
# NaT                   NaN         NaN  ...                      NaN
# NaT                   NaN         NaN  ...                      NaN
# NaT                   NaN         NaN  ...                      NaN
#
#        IQ_PERIODLENGTH_IS  IQ_EBT  IQ_EBITA  IQ_OTHER_NON_OPER_EXP_SUPPL  \
# Dates
# NaT                   NaN  -0.261       NaN                        0.001
# NaT                   NaN   1.007       NaN                          NaN
# NaT                   NaN   1.167       NaN                       -0.001
# NaT                   NaN   0.521       NaN                          NaN
#
#        IQ_EBITA_EXCL_SBC  IQ_DILUT_EPS_NORM  IQ_RESTATEMENT_IS  \
# Dates
# NaT                  NaN                NaN                NaN
# NaT                  NaN                NaN                NaN
# NaT                  NaN                NaN                NaN
# NaT                  NaN                NaN                NaN
#
#        IQ_TOTAL_REV_SHARE  IQ_EBITA_EQ_INC_EXCL_SBC
# Dates
# NaT                   NaN                       NaN
# NaT                   NaN                       NaN
# NaT                   NaN                       NaN
# NaT                   NaN                       NaN
#
# [4 rows x 77 columns]
